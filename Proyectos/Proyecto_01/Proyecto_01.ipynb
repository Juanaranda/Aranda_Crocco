# %% [markdown]
# ![](https://www.dii.uchile.cl/wp-content/uploads/2021/06/Magi%CC%81ster-en-Ciencia-de-Datos.png)

# %% [markdown]
# # **Proyecto 1 - MDS7202 Laboratorio de Programación Científica para Ciencia de Datos 📚**
#
# **MDS7202: Laboratorio de Programación Científica para Ciencia de Datos**
#
# ### Cuerpo Docente:
#
# - Profesor: Ignacio Meza, Gabriel Iturra
# - Auxiliar: Sebastián Tinoco
# - Ayudante: Arturo Lazcano, Angelo Muñoz
#
# *Por favor, lean detalladamente las instrucciones de la tarea antes de empezar a escribir.*
#
# ### Equipo:
#
# - Juan Aranda
# - Nicolás Crocco
#
#
# ### Link de repositorio de GitHub: `https://github.com/Juanaranda/Aranda_Crocco`
#
# Fecha límite de entrega 📆: 27 de Octubre de 2023.

# %% [markdown]
# ----
#
# ## Reglas
#
# - **Grupos de 2 personas.**
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Estrictamente prohibida la copia.
# - Pueden usar cualquier material del curso que estimen conveniente.

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://worldskateamerica.org/wp-content/uploads/2023/07/SANTIAGO-2023-1-768x153.jpg" alt="Descripción de la imagen">
# </div>
#
# En un Chile azotado por un profundo caos político-económico y el resurgimiento de programas de televisión de dudosa calidad, todas las miradas y esperanzas son depositadas en el éxito de un único evento: Santiago 2023. La nación necesitaba desesperadamente un respiro, y los Juegos de Santiago 2023 prometían ser una luz al final del túnel.
#
# El Presidente de la República -conocido en las calles como Bombín-, consciente de la importancia de este evento para la revitalización del país, decide convocar a usted y su equipo en calidad de expertos en análisis de datos y estadísticas. Con gran solemnidad, el presidente les encomienda una importante y peligrosa: liderar un proyecto que permitiera caracterizar de forma automática y eficiente los datos generados por estos magnos juegos. Para esto, el presidente le destaca que la solución debe considerar los siguientes puntos:
# - Caracterización automática de los datos
# - La solución debe ser compatible con cualquier dataset
# - Se les facilita el dataset *olimpiadas.parquet*, el cual recopila data de diferentes juegos olímpicos realizados en los últimos años

# %% [markdown]
# ## 1.1 Creación de `Profiler` Class (4.0 puntos)
#
# Cree la clase `Profiler`. Como mínimo, esta debe tener las siguientes funcionalidades:
#
# 1. El método constructor, el cual debe recibir los datos a procesar en formato `Pandas DataFrame`. Además, este método debe generar una carpeta en su directorio de trabajo con el nombre `EDA_fecha`, donde `fecha` corresponda a la fecha de ejecución en formato `DD-MM-YYYY`.
#
# 2. El método `summarize`, el cual debe caracterizar las variables del Dataset. Como mínimo, se espera que su método pueda:
#     - Implementar una funcionalidad para filtrar y aplicar este método a una o más variables de interés.
#     - Reportar el tipo de variable
#     - Reportar el número y/o porcentaje de valores únicos de la variable
#     - Reportar el número y/o porcentaje de valores nulos
#     - Si la variables es numérica:
#         - Reportar el número y/o porcentaje de valores cero, negativos y outliers
#         - Reportar estadística descriptiva como el valor mínimo, máximo, promedio y los percentiles 25, 50, 75 y 100
#    - Levantar una alerta en caso de encontrar alguna anomalía fuera de lo común (el criterio debe ser ajustable por el usuario)
#    - Guardar sus resultados en el directorio `EDA_fecha/summary.txt`. El archivo debe separar de forma clara y ordenada los resultados de cada punto.
#
# 3. El método `plot_vars`, el cual debe graficar la distribución e interraciones de las variables del Dataset. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/plots`
#     - Implementar una funcionalidad para filtrar y aplicar este método a una o más variables de interés.
#     - Para las variables numéricas:
#         - Genere un gráfico de distribución de densidad
#         - Grafique la correlación entre las variables
#     - Para las variables categóricas:
#         - Genere un histograma de las top N categorías (N debe ser un parámetro ajustable)
#         - Grafique el coeficiente V de Cramer entre las variables
#     - Guardar cada gráfico generado en la carpeta `EDA_fecha/plots` en formato `.pdf` y bajo el naming `variable.pdf`, donde `variable` es el nombre de la variable de interés
#
# 4. El método `clean_data`, el cual debe limpiar los datos para que luego puedan ser procesados. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/clean_data`
#     - Implementar una funcionalidad para filtrar y aplicar este método a una o más variables de interés.
#     - Drop de valores duplicados
#     - Implementar como mínimo 2 técnicas para tratar los valores nulos, como:
#         - Drop de valores nulos
#         - Imputar valores nulos con alguna técnica de imputación
#         - Funcionalidad para escoger entre una técnica y la otra.
#     - Una de las columnas del dataframe presenta datos *no atómicos*. Separe dicha columna en las columnas que la compongan.
#         - Hint: ¿Qué caracteres permiten separar una columna de otra?
#         - Para las pruebas con el dataset nuevo, puede esperar que exista al menos una columna con este tipo de problema. Asuma que los separadores serán los mismos, aunque el número de columnas a separar puede ser distinto.
#     - Deberían usar `FunctionTransformer`.
#     - Guardar los datos procesados en formato `.csv` en el path `EDA_fecha/clean_data/data.csv`
#
# 5. El método `scale`, el cual debe preparar adecuadamente los datos para luego ser consumidos por algún tipo de algoritmo. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/scale`
#     - Procesar de forma adecuada los datos numéricos y categóricos:
#         - Su método debe recibir las técnicas de escalamiento como argumento de entrada (utilizar solo técnicas compatibles con el framework de `sklearn`)
#         - Para los atributos numéricos, se transforme los datos con un escalador logarítmico y un `MinMaxScaler`
#         - Asuma que no existen datos ordinales en su dataset
#     - Guardar todo este procesamiento en un `ColumnTransformer`.
#     - Guardar los datos limpios y transformados en formato `.csv` en el path `EDA_fecha/process/scaled_features.csv`
#
# 6. El método `make_clusters`, el cual debe generar clusters de los datos usando algún algoritmo de clusterización. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/clusters`
#     - Generar un estudio del codo donde señale la cantidad de clusters optimos para el desarrollo.
#     - Su método debe recibir el algoritmo de clustering como argumento de entrada (utilizar solo algoritmos compatibles con el framework de `sklearn`).
#     - No olvide pre procesar adecuadamente los datos antes de implementar la técnica de clustering.
#     - En este punto es espera que generen un `Pipeline` de sklearn. Además, su método debería usar lo construido en los puntos 4 y 5.
#     - Su método debe ser capaz de funcionar a partir de datos crudos (se descontará puntaje de lo contrario).
#     - Una vez generado los clusters, proyecte los datos a 2 dimensiones usando su técnica de reducción de dimensionalidad favorita y grafique los resultados coloreando por cluster.
#     - Guardar los datos con su respectivo cluster en formato `.csv` en el path `EDA_fecha/clusters/data_clusters.csv`. Guarde también los gráficos generados en el mismo path.
#
# 7. El método `detect_anomalies`, el cual debe detectar anomalías en los datos. Como mínimo, se espera que su método pueda:
#
#     - Crear la carpeta `EDA/anomalies`
#     - Implementar alguna técnica de detección de anomalías.
#     - Al igual que el punto anterior, su método debe considerar los siguientes puntos:
#         - No olvide pre procesar de forma adecuada los datos antes de implementar la técnica de detección de anomalía.
#         - En este punto es espera que generen un `Pipeline` de sklearn. Además, su método debería usar lo construido en los puntos 4 y 5.
#         - Su método debe ser capaz de funcionar a partir de datos crudos (se descontará puntaje de lo contrario).
#         - Su método debe recibir el algoritmo como argumento de entrada
#         - Una vez generado las etiquetas, proyecte los datos a 2 dimensiones y grafique los resultados coloreando por las etiquetas predichas por el detector de anomalías
#     - Guardar los datos con su respectiva etiqueta en formato `.csv` en el path `EDA_fecha/anomalies/data_anomalies.csv`. Guarde también los gráficos generados en el mismo path.
#
# 8. El método `profile`, el cual debe ejecutar todos los métodos anteriores.
#
# 9. Crear el método `clearGarbage` para eliminar las carpetas/archivos creados/as por la clase `EDA`.
#
# Algunas consideraciones generales:
# - Su clase será testeada con datos tabulares diferentes a los provistos. No desarrollen código *hardcodeado*: su clase debe ser capaz de funcionar para **cualquier** dataset.
# - Aplique todo su conocimiento sobre buenas prácticas de programación: se evaluará que su código sea limpio y ordenado.
# - Recuerden documentar cada una de las funcionalidades que implementen.
# - Recuerden adjuntar sus `requirements.txt` junto a su entrega de proyecto. **El código que no se pueda ejecutar por incompatibilidades de librerías no será corregido.**

# %% [markdown]
# ### Cargar librerías

# %%
# Libreria Core del proyecto
import numpy as np
import pandas as pd
from datetime import date
import os
import shutil
from IPython.display import HTML

# Libreria para plotear (En colab esta desactualizado plotly)
# !pip install --upgrade plotly
# !pip install -U joblib

import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio

import matplotlib.pyplot as plt

# Librerias utiles
from sklearn.cluster import KMeans, SpectralClustering, MiniBatchKMeans, MeanShift, AffinityPropagation, Birch, AgglomerativeClustering
from sklearn.ensemble import IsolationForest
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, MaxAbsScaler, OneHotEncoder, LabelEncoder, OrdinalEncoder
from sklearn.impute import SimpleImputer

from scipy.stats import chi2_contingency

import joblib

# %%
# Cargamos los datos
try:
    from google.colab import drive
    drive.mount("/content/drive")
    path = '/content/drive/MyDrive/Proyecto_01'
    path1 = '/content/drive/MyDrive/12vo Semestre/Laboratorio de Programación Científica/Proyecto_01'
except:
    print('Ignorando conexión drive-colab')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_parquet(path+"/olimpiadas.parquet")
print(f"Dimensiones del dataset {df.shape}")
print("----------------------------")
print("Muestra del dataset:")
print(df.columns)
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/nicocrocco/Desktop/Universidad/Semestres/12vo Semestre/Laboratorio de Programación Científica/Proyecto/Proyecto_01/Proyecto_01_V5_pipelines.ipynb Celda 9 line 1
# ----> <a href='vscode-notebook-cell:/Users/nicocrocco/Desktop/Universidad/Semestres/12vo%20Semestre/Laboratorio%20de%20Programaci%C3%B3n%20Cient%C3%ADfica/Proyecto/Proyecto_01/Proyecto_01_V5_pipelines.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_parquet(path+"/olimpiadas.parquet")
#       <a href='vscode-notebook-cell:/Users/nicocrocco/Desktop/Universidad/Semestres/12vo%20Semestre/Laboratorio%20de%20Programaci%C3%B3n%20Cient%C3%ADfica/Proyecto/Proyecto_01/Proyecto_01_V5_pipelines.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> print(f"Dimensiones del dataset {df.shape}")
# ...

# %%
# Cargar archivos en local
# !pip install -U pyarrow
df = pd.read_parquet("olimpiadas.parquet", engine='pyarrow')
print(f"Dimensiones del dataset {df.shape}")
print("----------------------------")
print("Muestra del dataset:")
df.head(10)
# Out:
# ...
# Dimensiones del dataset (271116, 13)
# ----------------------------
# Muestra del dataset:
#    ID                      Name Sex            Team  NOC        Games  Year  \
# 0   1                 A Dijiang   M           China  CHN  1992 Summer  1992
# 1   2                  A Lamusi   M           China  CHN  2012 Summer  2012
# 2   3       Gunnar Nielsen Aaby   M         Denmark  DEN  1920 Summer  1920
# 3   4      Edgar Lindenau Aabye   M  Denmark/Sweden  DEN  1900 Summer  1900
# 4   5  Christine Jacoba Aaftink   F     Netherlands  NED  1988 Winter  1988
# 5   5  Christine Jacoba Aaftink   F     Netherlands  NED  1988 Winter  1988
# 6   5  Christine Jacoba Aaftink   F     Netherlands  NED  1992 Winter  1992
# 7   5  Christine Jacoba Aaftink   F     Netherlands  NED  1992 Winter  1992
# 8   5  Christine Jacoba Aaftink   F     Netherlands  NED  1994 Winter  1994
# 9   5  Christine Jacoba Aaftink   F     Netherlands  NED  1994 Winter  1994
#
# ...

# %% [markdown]
# ### Clase Profiler

# %%
class Profiler():
    def __init__(self, data):
        self.data = data
        self.date = date.today().strftime("%d-%m-%Y")
        self.output_folder = f"EDA_{self.date}"


        # Crea la carpeta EDA con la fecha actual
        os.makedirs(self.output_folder, exist_ok=True)

# Summarize
    def summarize(self, columns_of_interest=None, outlier_threshold=3):
        """
        Genera un resumen de estadísticas y características para las variables del conjunto de datos. Esto incluye el tipo de variable,
        el número de valores únicos, el porcentaje de valores nulos, el número y porcentaje de valores cero (solo para variables numéricas),
        estadísticas descriptivas y la detección de outliers. 
        
        Guarda un archivo de resumen en la carpeta de salida.

        Parámetros
        ----------
        columns_of_interest: list, default=None
            Lista de columnas a resumir. Si es None, se resumen todas las columnas.
        
        outlier_threshold: int, default=3
            Umbral para detectar outliers en variables numéricas (valor por encima o por debajo del umbral).
        """
        # Si no se especifican columnas de interés, se resumen todas las columnas
        if columns_of_interest is None:
            columns_of_interest = self.data.columns

        summary_file = os.path.join(self.output_folder, "summary.txt")

        with open(summary_file, "w") as file:
            for column in columns_of_interest:
                file.write(f"Variable: {column}\n")

                # Tipo de variable
                variable_type = str(self.data[column].dtype)
                file.write(f"Tipo de Variable: {variable_type}\n")

                # Número de valores únicos
                num_unique = self.data[column].nunique()
                file.write(f"Número de Valores Únicos: {num_unique}\n")

                # Porcentaje de valores únicos
                pct_unique = (num_unique / len(self.data)) * 100
                file.write(f"Porcentaje de Valores Únicos: {pct_unique:.2f}%\n")

                # Número de valores nulos
                num_null = self.data[column].isnull().sum()
                file.write(f"Número de Valores Nulos: {num_null}\n")

                # Porcentaje de valores nulos
                pct_null = (num_null / len(self.data)) * 100
                file.write(f"Porcentaje de Valores Nulos: {pct_null:.2f}%\n")

                # Si la variable es numérica
                if pd.api.types.is_numeric_dtype(self.data[column]):
                    # Número de valores cero
                    num_zeros = (self.data[column] == 0).sum()
                    file.write(f"Número de Valores Cero: {num_zeros}\n")

                    # Porcentaje de valores cero
                    pct_zeros = (num_zeros / len(self.data)) * 100
                    file.write(f"Porcentaje de Valores Cero: {pct_zeros:.2f}%\n")

                    # Estadísticas descriptivas
                    descriptive_stats = self.data[column].describe()
                    file.write("Estadísticas Descriptivas:\n")
                    file.write(descriptive_stats.to_string() + "\n")

                    # Detectar outliers (valores que están por encima o por debajo del umbral definido)
                    upper_threshold = descriptive_stats["75%"] + (outlier_threshold * (descriptive_stats["75%"] - descriptive_stats["25%"]))
                    lower_threshold = descriptive_stats["25%"] - (outlier_threshold * (descriptive_stats["75%"] - descriptive_stats["25%"]))
                    outliers = ((self.data[column] > upper_threshold) | (self.data[column] < lower_threshold)).sum()
                    file.write(f"Número de Outliers (umbral={outlier_threshold}): {outliers}\n")

                    # Si hay outliers, generar una alerta
                    if outliers > 0:
                        file.write("ALERTA: Se encontraron outliers en esta variable.\n")

                # Separador entre variables
                file.write("-" * 50 + "\n")

# Plot vars
    def plot_vars(self, columns_of_interest=None, top_n=10):
        """
        Genera visualizaciones para las variables del conjunto de datos. Puede incluir histogramas para variables numéricas
        y gráficos de barras para variables categóricas. 
        
        Guarda visualizaciones en una carpeta especificada.

        Parámetros
        ----------
        columns_of_interest: list
            Lista de columnas a visualizar. Si es None, se utilizarán todas las columnas.
        top_n: int
            Número de categorías más comunes a mostrar en gráficos de barras para variables categóricas.
        """
        if columns_of_interest is None:
            columns_of_interest = self.data.columns
        plots_folder = os.path.join(self.output_folder, "plots")
        os.makedirs(plots_folder, exist_ok=True)

        for column in columns_of_interest:
            if column in self.data.select_dtypes(include=[np.number]).columns:
                self.plot_numeric_variable(column, plots_folder)
            elif column in self.data.select_dtypes(include=["object"]).columns:
                self.plot_categorical_variable(column, plots_folder, top_n)

    def plot_numeric_variable(self, column, plots_folder):
        """
        Genera visualizaciones para una variable numérica dada, incluyendo un histograma de densidad y una matriz de correlación.

        Guarda las visualizaciones en la carpeta especificada.

        Parámetros
        ----------
        column: str
            El nombre de la columna numérica a visualizar.
        
        plots_folder: str
            Ruta de la carpeta donde se guardarán las visualizaciones.
        """
        fig = px.histogram(self.data, x=column, title=f'Distribución de densidad para {column}', nbins=20)
        fig.update_layout(xaxis_title=column, yaxis_title='Densidad')
        fig.update_xaxes(categoryorder="total descending")

        plot_file = os.path.join(plots_folder, f"{column}_density.pdf")
        pio.write_image(fig, plot_file, format="pdf")

        corr = self.data.select_dtypes(include=[np.number]).corr()
        fig = go.Figure(data=go.Heatmap(z=corr.values, x=corr.index, y=corr.columns, colorscale='viridis', zmin=-1, zmax=1))
        fig.update_layout(title=f'Correlación entre {column} y las demás variables numéricas')

        corr_plot_file = os.path.join(plots_folder, f"correlation_{column}.pdf")
        pio.write_image(fig, corr_plot_file, format="pdf")

    def plot_categorical_variable(self, column, plots_folder, top_n):
        """
        Genera visualizaciones para una variable categórica dada, incluyendo un histograma de las categorías más comunes y una matriz
        de coeficiente de Cramer para evaluar la asociación con otras variables categóricas.

        Guarda visualizaciones en la carpeta especificada.

        Parámetros
        ----------
        column: str
            El nombre de la columna categórica a visualizar.
        
        plots_folder: str
            Ruta de la carpeta donde se guardarán las visualizaciones.
        
        top_n: int
            Número de categorías más comunes a mostrar en el histograma.
        """
        top_categories = self.data[column].value_counts().head(top_n).reset_index()
        top_categories.columns = [column, 'Frecuencia']

        fig = px.bar(top_categories, x=column, y='Frecuencia', title=f'Histograma de las {top_n} categorías más comunes en {column}')
        fig.update_xaxes(categoryorder="total descending")
        fig.update_xaxes(title_text=column)
        fig.update_yaxes(title_text='Frecuencia')

        plot_file = os.path.join(plots_folder, f"{column}.pdf")
        pio.write_image(fig, plot_file, format="pdf")

        if column != self.data.select_dtypes(include=["object"]).columns[-1]:
            associations = pd.DataFrame(index=self.data.select_dtypes(include=["object"]).columns, columns=[column])
            for col1 in self.data.select_dtypes(include=["object"]).columns:
                if col1 != column:
                    confusion_matrix = pd.crosstab(self.data[col1], self.data[column])
                    chi2, _, _, _ = chi2_contingency(confusion_matrix)
                    n = self.data.shape[0]
                    phi2 = chi2 / n
                    r, k = confusion_matrix.shape
                    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))
                    rcorr = r - ((r-1)**2)/(n-1)
                    kcorr = k - ((k-1)**2)/(n-1)
                    cramer_v = np.sqrt(phi2corr / (min((kcorr-1), (rcorr-1))))
                    associations.at[col1, column] = cramer_v

            fig = px.imshow(associations,
                x=associations.columns, y=associations.index,
                color_continuous_scale='viridis',
                labels=dict(x="Variable", y="Variable", color="Cramer V"),
                title=f'Coeficiente V de Cramer entre variables categóricas')

            cramer_plot_file = os.path.join(plots_folder, f"cramer_{column}.pdf")
            pio.write_image(fig, cramer_plot_file, format="pdf")

# Clean data
    def dtype_transform(self, data, max_categoric_value):
        """
        Transforma las columnas tipo number y object que tengan 10 o menos datos únicos, en columnas categóricas.

        Parámetros
        ----------
        data: Dataframe
            Proveniente de función scale, este debe venir ya procesado por el método clean_data

        max_categoric_value: int, dafault=10 
            Cantidad máxima de valores únicos que puede tener una columna para ser tratada como categórica.

        Retorna
        -------
        data: Dataframe
            Contiene las columnas transformadas.
        """
        num_cols = data.select_dtypes(include='number').columns

        # Obtener las columnas que no son numéricas
        non_numeric_cols = data.select_dtypes(exclude=['number']).columns

        # Iterar sobre las columnas no numéricas y tratar de convertirlas a numéricas
        for col in non_numeric_cols:
            try:
                data[col] = pd.to_numeric(data[col])
            except ValueError:
                continue

        obj_cols = data.select_dtypes(include='object').columns

        # Convertir columnas numéricas con 10 o menos valores únicos a categóricas
        data[num_cols[data[num_cols].nunique() <= 10]] = data[num_cols[data[num_cols].nunique() <= 10]].astype('category')

        # Convertir columnas no numéricas con max_categoric_value o menos valores únicos a categóricas
        data[obj_cols[data[obj_cols].nunique() <= max_categoric_value]] = data[obj_cols[data[obj_cols].nunique() <= max_categoric_value]].astype('category')

        return data

    def get_imputer(self, data):
        """
        Realiza la imputación de valores nulos en un conjunto de datos.

        Los valores nulos en las columnas numéricas se imputan utilizando la estrategia de la media,
        mientras que en las columnas categóricas se utiliza la estrategia del valor más frecuente.

        Parámetros
        ----------
        data: DataFrame
            Conjunto de datos que se va a imputar.

        Retorna
        -------
        - data: DataFrame
            Contiene valores nulos imputados.
        """
        # Identificar las columnas numéricas y categóricas
        numeric_columns = data.select_dtypes(include='number').columns
        categorical_columns = data.select_dtypes(include='category').columns

        # Imputar columnas numéricas
        numeric_imputer = SimpleImputer(strategy='mean')
        data[numeric_columns] = numeric_imputer.fit_transform(data[numeric_columns])

        # Imputar columnas categóricas
        #categorical_imputer = SimpleImputer(strategy='most_frequent')
        #data[categorical_columns] = categorical_imputer.fit_transform(data[categorical_columns])
        for col in categorical_columns:
            if "No Value" not in data[col].cat.categories:
                data[col] = data[col].cat.add_categories("No Value")
            # Llenar valores nulos con "No Value"
            data[col].fillna('No Value', inplace=True)

        return data

    def clean_data(self, columns_of_interest=None, max_categoric_value=1000, null_handling_method="drop", column_name_to_split=None):
        """
        Realiza la limpieza y preprocesamiento de un conjunto de datos.

        Permite separar columnas no atómicas, eliminar duplicados y tratar los valores nulos según la estrategia especificada.

        Los datos procesados se guardan en un archivo CSV en una carpeta llamda "clean_data" dentro del directorio de trabajo.

        Crea un transformer que puede ser entregado en métodos posteriorires dentro de un pipeline.

        Parámetros
        ----------
        columns_of_interest: list
            Lista de columnas de interés para el procesamiento. Si es None, se consideran todas las columnas.

        max_categoric_value: int, default=1000
            Cantidad máxima de valores únicos que puede tener una columna para ser tratada como categórica.
        
        null_handling_method: str, {'drop', 'impute'}='drop'
            Método para tratar los valores nulos.
                'drop': elimina filas con valores nulos.
                
                'impute': valores nulos númericos de las filas son imputados utilizando la estrategia de la media
                        y en los valores categóricos se utiliza la estrategia del valor más frecuente.
        
        column_name_to_split: int, default=None
            Nombre de la columna a separar si es relevante.

        Retorna
        -------
        cleaned_data: Dataframe
            Dataframe de la data limpia.
        """
        # Crear carpeta EDA/clean_data
        clean_data_folder = os.path.join(self.output_folder, "clean_data")
        os.makedirs(clean_data_folder, exist_ok=True)

        # Copiar el DataFrame para evitar modificar el original
        cleaned_data = self.data.copy()
        
        # Definir una función que permita guardar el procesamiento dentro de un FunctionTransformer
        def cleaning_data(data):
            # Separar columnas no atómicas
            if column_name_to_split:
                transformer = FunctionTransformer(lambda x: x.str.split(r'[(*?:]', expand=True))
                split_columns = transformer.transform(data[column_name_to_split])
                # Renombrar las columnas según la separación
                split_columns.columns = column_name_to_split.split('-')

                # Reemplazar 'NaN' con NaN real en las columnas separadas
                split_columns = split_columns.replace('NaN', np.nan)
                split_columns = split_columns.replace('nan', np.nan)
                split_columns = split_columns.replace('0.0', np.nan)

                # Eliminar columna a dividir del Dataframe original
                data.drop(column_name_to_split, axis=1, inplace=True)

                # Incorporar las columnas divididas al Dataframe original
                data = pd.concat([data, split_columns], axis=1)

            # Transformar columnas del dataset a numéricas y categóricas según corresponda
            data = self.dtype_transform(data, max_categoric_value)

            # Eliminar valores duplicados
            data.drop_duplicates(inplace=True)

            # Tratar valores nulos
            if null_handling_method == "drop":
                if columns_of_interest is not None:
                    data.dropna(subset=columns_of_interest, inplace=True)
                else:
                    data.dropna(inplace=True)

            elif null_handling_method == "impute":
                data = self.get_imputer(data)
                data.select_dtypes(include='number').fillna(0, inplace=True)
                #data.select_dtypes(include='category').fillna('No Value', inplace=True)
                #data.fillna(0, inplace=True)

            else:
                print("Método de tratamiento de nulos no válido.")
                return
            
            return data

        # Crear un FunctionTransformer para realizar la limpieza del dataset
        data_cleaner = FunctionTransformer(cleaning_data)
        cleaned_data = data_cleaner.fit_transform(cleaned_data)
        cleaned_data = pd.DataFrame(cleaned_data)

        # Guardar los datos procesados en formato .csv en la carpeta EDA/clean_data
        cleaned_data.to_csv(os.path.join(clean_data_folder, "data.csv"), index=False)

        # Crear atributos para poder usarlo en otros métodos
        self.clean_data_transformer = data_cleaner # Trasnformador
        self.data_cleaned = cleaned_data # Dataframe con datos limpios
        self.max_categoric_value = max_categoric_value # Valor de camtidad de categorías

        return cleaned_data

# Scale
    def scale(self, categorical_scaler=None, numeric_scaler_stack=False, *numeric_scaler):
        """
        Realiza el escalamiento de un conjunto de datos almacenado en un archivo CSV. Los datos se leen desde el archivo
        y se aplican transformaciones.
        Aplica escaladores logarítmicos y MinMax a las columnas numéricas y, opcionalmente, un codificador OneHot a las columnas categóricas.
        Retorna un transformador que puede ser utilizado posteriormente en otros métodos.

        Parámetros
        ----------
        categorical_scaler: str, {'OneHotEncoder', 'OrdinalEncoder', None}, default=None
            Indica si se usará o no un encoder para codificar datos categóricos.

        numeric_scaler_stack: bool, default=False 
            Indica si deben apilarse los escaladores numéricos que se ingresen como input sobre los escaladores existentes en la función.

        *numeric_scaler: *arg
            Argumento que permite ingresar escaladores numéricos de la libreria Scikit-learn.
            Ejemplo: RobustScaler()

        Retorna
        -------
        - preprocessor: ColumnTransformer
            Transformer que realiza el escalamiento de los datos. Puede ser utilizado en otros métodos.
        """

        # Crear la carpeta EDA_fecha/scale
        scale_folder = os.path.join(self.output_folder, "scale")
        os.makedirs(scale_folder, exist_ok=True)

        # Crear una copia de la data original ya limpia
        data = self.data_cleaned.copy()

        # Transformar columnas del dataset a categóricas según corresponda
        #data = self.dtype_transform(data, max_categoric_value)

        # Obtener columnas numéricas y categóricas
        num_cols = data.select_dtypes(include='number').columns
        cat_cols = data.select_dtypes(include='category').columns

        # Obtener columnas a transformar con escaladores numéricos
        numeric_features = num_cols.tolist()

        # Escalador Logarítmico y MinMaxScaler
        numeric_transformer = Pipeline(steps=[('scaler', StandardScaler()),
                                            ('minmax', MinMaxScaler())])

        transformers = [('num', numeric_transformer, numeric_features)]

        # Si se introduce algún *numeric_scaler
        if len(numeric_scaler) > 0:
            if numeric_scaler_stack == True:
                # Agregamos los escaladores al pipeline numeric_transformer
                pasos = [('scaler', StandardScaler()),
                        ('minmax', MinMaxScaler())]
                for scaler in numeric_scaler:
                    step_name = f'{scaler}'
                    pasos.append((step_name, scaler))
                numeric_transformer = Pipeline(steps=pasos)
                transformers = [('num', numeric_transformer, numeric_features)]
            elif numeric_scaler_stack == False:
                # Agregamos los escaladores al un nuevo pipeline
                for scaler in numeric_scaler:
                    step_name = f'{scaler}'
                    new_numeric_transformer = Pipeline(steps=[(step_name, scaler)])
                    transformers.append((step_name, new_numeric_transformer, numeric_features))


        # Si categorical_scaler es True
        if categorical_scaler is not None:
            categorical_features = cat_cols.tolist()
            if categorical_scaler == 'OneHotEncoder':
                # Agregamos OneHotEncoder al pipeline
                categorical_transformer = Pipeline(steps=[('onehot', OneHotEncoder(drop='if_binary', handle_unknown='ignore'))])
                transformers.append(('cat', categorical_transformer, categorical_features))
            
            elif categorical_scaler == 'OrdinalEncoder':
                # Agregamos OneHotEncoder al pipeline
                categorical_transformer = Pipeline(steps=[('ordinal', OrdinalEncoder())])
                transformers.append(('cat', categorical_transformer, categorical_features))

        # Crear un ColumnTransformer realizar el escalamiento del dataset
        preprocessor = ColumnTransformer(transformers, remainder='drop')
        scaled_data = preprocessor.fit_transform(data)

        # Obtener los nombres de las columnas después de la transformación
        column_names = preprocessor.get_feature_names_out()
        scaled_df = pd.DataFrame(scaled_data, columns=column_names)

        # Crear atributo scale_transformer para poder usarlo en otros métodos
        self.scale_transformer = preprocessor

        # Crear atributo para guardar nombre de columnas del dataset escalado
        self.scale_columns = column_names

        # Crear atributo para guardar data escalada
        self.scaled_data = scaled_df

        # Guardar el ColumnTransformer para su uso posterior
        transformer_file = os.path.join(scale_folder, "column_transformer.pkl")
        joblib.dump(preprocessor, transformer_file)

        # Guardar los datos escalados en un archivo CSV
        scaled_df.to_csv(os.path.join(scale_folder, "scaled_features.csv"), index=False)

        return preprocessor

# Make clusters
    def make_clusters(self, clustering_algorithm="KMeans", max_clusters=10):
        """
        Funciona a partir de la data previamente escalada con el método scale, por lo que los métodos clean_data y scale
        deben haber sido utilizados previamente.

        Mediante un pipeline, se llaman a los transformers generados en los métodos clean_data y scale, además de aplicar el algorítmos
        de custerización indicado en el input del método.

        Clusteriza los datos entregados y crea una columna con las etiquetas de clusters en el dataset.

        Genera un gráfico con el método del codo, a partir de la cual se debe indicar en un input la cantidad de clusters deseadas para realizar la clusterización de los datos.

        Crea un gráfico en 2 dimensiones de los datos clusterizados y diferenciados cada cluster por color.

        Parámetros
        ----------
        clustering_algorithm: {'AffinityPropagation', 'AgglomerativeClustering', 'Birch', 'KMeans', 'MiniBatchKMeans', 'MeanShift', 'SpectralClustering'}, default='KMeans'. 
            Algorítmo de clustering deseado.

        max_clusters: int, default=10. 
            Cantidad máxima de clusters admitida.
        """
        
        # Hacer una copia del dataset original
        data = self.data.copy()

        # Crear el pipeline con las etapas de limpieza y escalado
        preprocessing_pipeline = Pipeline([
            ('clean_data', self.clean_data_transformer),
            ('scale', self.scale_transformer)
        ])

        # Aplicar el pipeline a los datos crudos
        cleaned_and_scaled_data = preprocessing_pipeline.fit_transform(data)

        # Convertir el resultado a un DataFrame
        cleaned_and_scaled_data = pd.DataFrame(cleaned_and_scaled_data, columns=self.scale_columns)

        # Crear la carpeta EDA_fecha/clusters
        clusters_folder = os.path.join(self.output_folder, "clusters")
        os.makedirs(clusters_folder, exist_ok=True)

        # Realizar método del codo para definir cantidad de clusters a aplicar
        # Inicializar una lista para almacenar las sumas de cuadrados intra-cluster
        wcss = []
            
        # Evaluar diferentes números de clusters
        for i in range(1, max_clusters + 1):
            kmeans = KMeans(n_clusters=i, random_state=42)
            kmeans.fit(cleaned_and_scaled_data)
            # Calcular la suma de cuadrados intra-cluster y agregarla a la lista
            wcss.append(kmeans.inertia_)

        # Graficar el método del codo para seleccionar el número óptimo de clusters
        plt.figure(figsize=(8, 6))
        plt.plot(range(1, max_clusters + 1), wcss, marker='o', linestyle='--')
        plt.xlabel('Número de Clusters')
        plt.ylabel('Suma de Cuadrados Intra-cluster (WCSS)')
        plt.title('Método del Codo')
        plt.savefig(os.path.join(clusters_folder, "elbow_method.png"))

        plt.show()

        # Pedir al usuario que ingrese el número deseado de clusters
        selected_num_clusters = int(input("Ingresa el número de clusters deseado: "))

        # Definir el modelo a entrenar según input del método
        if clustering_algorithm == 'MiniBatchKMeans':
            algorithm = MiniBatchKMeans(n_clusters=selected_num_clusters, random_state=42)

        elif clustering_algorithm == 'SpectralClustering':
            algorithm = SpectralClustering(n_clusters=selected_num_clusters, assign_labels='kmeans', random_state=42)

        elif clustering_algorithm == 'Birch':
            algorithm = Birch(n_clusters=selected_num_clusters)

        elif clustering_algorithm == 'AgglomerativeClustering':
            algorithm = AgglomerativeClustering(n_clusters=selected_num_clusters)

        elif clustering_algorithm == 'AffinityPropagation':
            algorithm = AffinityPropagation(random_state=42)
        
        elif clustering_algorithm == 'MeanShift':
            algorithm = MeanShift()
        
        else:
            algorithm = KMeans(n_clusters=selected_num_clusters, random_state=42)

        # Crear pipeline con preprocesamiento y clusterización
        clustering_pipe = Pipeline([
            ('preprocessing',preprocessing_pipeline),
            ('clustering', algorithm)
        ])

        # Hacer una nueva copia del dataset original y 
        data = self.data.copy()
        # Aplicar pipeline
        cluster_labels = clustering_pipe.fit_predict(data)

        # Guardar los datos con su respectivo cluster
        cluster_data = cleaned_and_scaled_data.copy()
        cluster_data["Cluster"] = cluster_labels
        cluster_data.to_csv(os.path.join(clusters_folder, "data_clusters.csv"), index=False)

        # Reducción de dimensionalidad y proyección de datos en 2D
        pca = PCA(n_components=2)
        reduced_data = pca.fit_transform(cleaned_and_scaled_data)

        # Graficar la proyección de datos coloreada por cluster
        plt.figure(figsize=(8, 6))
        plt.scatter(reduced_data[:, 0], reduced_data[:, 1], c=cluster_labels)
        plt.xlabel('PC1')
        plt.ylabel('PC2')
        plt.title('Proyección de Datos con Coloreo por Cluster')
        plt.savefig(os.path.join(clusters_folder, "data_projection.png"))

        # Mostrar y guardar los gráficos
        plt.show()

# Detect anomalies
    def detect_anomalies(self, algorithm):
        """
        Funciona a partir de la data previamente escalada con el método scale, por lo que los métodos clean_data y scale
        deben haber sido utilizados previamente.

        Mediante un pipeline, se llaman a los transformers generados en los métodos clean_data y scale, además de aplicar el algoritmo
        de clustering indicado en el input del método.

        Detecta anomalías en los datos entregados y crea una columna con las etiquetas de anomalías en el dataset.

        Genera un gráfico con el método del codo, a partir del cual se debe indicar en un input la
        cantidad de clusters deseadas para realizar la clusterización de los datos.

        Parámetros
        ----------
        algorithm: estimator, default=IsolationForest()
            Algoritmo de detección de anomalías de scikit-learn, por ejemplo, OneClassSVM, IsolationForest, EllipticEnvelope, etc.
        """
        # Crear la carpeta EDA_fecha/anomalies
        anomalies_folder = os.path.join(self.output_folder, "anomalies")
        os.makedirs(anomalies_folder, exist_ok=True)
        
        # Hacer una copia del dataset original
        data = self.data.copy()

        # Crear el pipeline con las etapas de limpieza y escalado
        preprocessing_pipeline = Pipeline([
            ('clean_data', self.clean_data_transformer),
            ('scale', self.scale_transformer)
        ])

        # Aplicar el pipeline a los datos crudos
        cleaned_and_scaled_data = preprocessing_pipeline.fit_transform(data)

        # Convertir el resultado a un DataFrame
        cleaned_and_scaled_data = pd.DataFrame(cleaned_and_scaled_data, columns=self.scale_columns)

        if algorithm is None:
            algorithm = IsolationForest()

        # Entrenar el detector de anomalías
        anomaly_detector = algorithm.fit(cleaned_and_scaled_data)

        # Predecir las anomalías en los datos
        anomaly_labels = anomaly_detector.predict(cleaned_and_scaled_data)

        # Guardar los datos con etiquetas de anomalías en formato CSV
        anomalies_data = cleaned_and_scaled_data.copy()
        anomalies_data['anomaly_label'] = anomaly_labels
        anomalies_file = os.path.join(anomalies_folder, "data_anomalies.csv")
        anomalies_data.to_csv(anomalies_file, index=False)

        # Proyectar los datos en 2D para graficar
        pca = PCA(n_components=2)  # Proyección a 2 dimensiones para graficar
        projected_data = pca.fit_transform(cleaned_and_scaled_data)

        # Graficar los datos coloreando por las etiquetas de anomalías
        plt.figure(figsize=(8, 6))
        plt.scatter(projected_data[:, 0], projected_data[:, 1], c=anomaly_labels, cmap='viridis')
        plt.title('Detección de Anomalías')
        plt.xlabel('Dimensión 1')
        plt.ylabel('Dimensión 2')
        plt.colorbar()
        plt.savefig(os.path.join(anomalies_folder, 'anomalies_plot.png'))
        plt.close()


# Profile
    def profile(self, clusters_algorithm='KMeans',anomalies_algorithm=None):
        '''
        Llama a todos los métodos de la clase profiler en orden.
        '''
        # Llamar a los métodos en el orden deseado
        self.summarize()
        self.plot_vars()
        self.clean_data()
        self.scale()
        self.make_clusters(clusters_algorithm)
        if anomalies_algorithm:
            self.detect_anomalies(anomalies_algorithm)


# clearGarbage
    def clearGarbage(self):
        """
        Elimina todos los archivos y carpetas existentes dentro del directorio de trabajo.
        """
        if os.path.exists(self.output_folder):
            # Elimina el directorio de salida y su contenido de forma recursiva
            shutil.rmtree(self.output_folder)
            print(f"Se ha eliminado el contenido de {self.output_folder}")
        else:
            print(f"El directorio {self.output_folder} no existe.")

# %% [markdown]
# ### Activar Profiler

# %%
# Activar instancia Profiler
pro = Profiler(df)

# %% [markdown]
# ### Probar Summarize

# %%
# Probamos método summarize
pro.summarize(None, 3)

# %% [markdown]
# ### Probar Plot_vars

# %%
# Probamos método plot_vars
pro.plot_vars(columns_of_interest=['NOC','Games','Event','Sex','Team','Year','Season','Sport','City','Medal'], top_n=5)

# %% [markdown]
# ### Probar Clean_data

# %%
# Probamos método clean_data
pro.clean_data(columns_of_interest=None, null_handling_method="drop", column_name_to_split='age-height-weight')
# Out:
#             ID                                 Name Sex          Team  NOC  \
# 40          16             Juhamatti Tapio Aaltonen   M       Finland  FIN
# 41          17              Paavo Johannes Aaltonen   M       Finland  FIN
# 42          17              Paavo Johannes Aaltonen   M       Finland  FIN
# 44          17              Paavo Johannes Aaltonen   M       Finland  FIN
# 48          17              Paavo Johannes Aaltonen   M       Finland  FIN
# ...        ...                                  ...  ..           ...  ...
# 271078  135553  Galina Ivanovna Zybina (-Fyodorova)   F  Soviet Union  URS
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  Soviet Union  URS
# 271082  135554                         Bogusaw Zych   M        Poland  POL
# 271102  135563            Olesya Nikolayevna Zykina   F        Russia  RUS
# 271103  135563            Olesya Nikolayevna Zykina   F        Russia  RUS
#
#               Games  Year  Season       City       Sport  \
# ...

# %%
pro.clean_data(columns_of_interest=None, null_handling_method="impute", column_name_to_split='age-height-weight')
# Out:
#               ID                      Name Sex            Team  NOC  \
# 0            1.0                 A Dijiang   M           China  CHN
# 1            2.0                  A Lamusi   M           China  CHN
# 2            3.0       Gunnar Nielsen Aaby   M         Denmark  DEN
# 3            4.0      Edgar Lindenau Aabye   M  Denmark/Sweden  DEN
# 4            5.0  Christine Jacoba Aaftink   F     Netherlands  NED
# ...          ...                       ...  ..             ...  ...
# 271111  135569.0                Andrzej ya   M        Poland-1  POL
# 271112  135570.0                  Piotr ya   M          Poland  POL
# 271113  135570.0                  Piotr ya   M          Poland  POL
# 271114  135571.0        Tomasz Ireneusz ya   M          Poland  POL
# 271115  135571.0        Tomasz Ireneusz ya   M          Poland  POL
#
#               Games    Year  Season            City          Sport  \
# 0       1992 Summer  1992.0  Summer       Barcelona     Basketball
# ...

# %% [markdown]
# ### Probar Scale

# %%
# Probamos método scale con columnas solo numéricas
pro.scale('OrdinalEncoder')
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('scaler', StandardScaler()),
#                                                  ('minmax', MinMaxScaler())]),
#                                  ['ID', 'Year', 'age', 'height', 'weight']),
#                                 ('cat',
#                                  Pipeline(steps=[('ordinal',
#                                                   OrdinalEncoder())]),
#                                  ['Sex', 'NOC', 'Games', 'Season', 'City',
#                                   'Sport', 'Event', 'Medal'])])

# %%
# Revisamos dataset escalado sólo con columna numéricas
scaled_df = pd.read_csv('EDA_10-11-2023/scale/scaled_features.csv')
scaled_df.head(10)
# Out:
#     num__ID  num__Year  num__age  num__height  num__weight  cat__Sex  \
# 0  0.000000   0.800000  0.160920     0.535354     0.291005       1.0
# 1  0.000007   0.966667  0.149425     0.434343     0.185185       1.0
# 2  0.000015   0.200000  0.160920     0.488272     0.241808       1.0
# 3  0.000022   0.033333  0.275862     0.488272     0.241808       1.0
# 4  0.000030   0.766667  0.126437     0.585859     0.301587       0.0
# 5  0.000030   0.766667  0.126437     0.585859     0.301587       0.0
# 6  0.000030   0.800000  0.172414     0.585859     0.301587       0.0
# 7  0.000030   0.800000  0.172414     0.585859     0.301587       0.0
# 8  0.000030   0.816667  0.195402     0.585859     0.301587       0.0
# 9  0.000030   0.816667  0.195402     0.585859     0.301587       0.0
#
#    cat__NOC  cat__Games  cat__Season  cat__City  cat__Sport  cat__Event  \
# 0      41.0        37.0          0.0        5.0         8.0       159.0
# ...

# %%
# Probamos método scale con columnas categóricas
pro.scale('OrdinalEncoder', False, RobustScaler())
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('scaler', StandardScaler()),
#                                                  ('minmax', MinMaxScaler())]),
#                                  ['ID', 'Year', 'age', 'height', 'weight']),
#                                 ('RobustScaler()',
#                                  Pipeline(steps=[('RobustScaler()',
#                                                   RobustScaler())]),
#                                  ['ID', 'Year', 'age', 'height', 'weight']),
#                                 ('cat',
#                                  Pipeline(steps=[('ordinal',
#                                                   OrdinalEncoder())]),
#                                  ['Sex', 'NOC', 'Games', 'Season', 'City',
#                                   'Sport', 'Event', 'Medal'])])

# %% [markdown]
# ### Probar Make_clusters

# %%
# Probamos método make_clusters
pro.make_clusters('MiniBatchKMeans')
# Out:
# /opt/anaconda3/envs/py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/anaconda3/envs/py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/anaconda3/envs/py3.10/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
# Revisamos dataset clusterizado
clustered_df = pd.read_csv('EDA_10-11-2023/clusters/data_clusters 3.csv')
clustered_df
# Out:
#          num__ID  num__Year  num__age  num__height  num__weight  cat__Sex  \
# 0       0.000000   0.800000  0.160920     0.535354     0.291005       1.0
# 1       0.000007   0.966667  0.149425     0.434343     0.185185       1.0
# 2       0.000015   0.200000  0.160920     0.488272     0.241808       1.0
# 3       0.000022   0.033333  0.275862     0.488272     0.241808       1.0
# 4       0.000030   0.766667  0.126437     0.585859     0.301587       0.0
# ...          ...        ...       ...          ...          ...       ...
# 269726  0.999985   0.666667  0.218391     0.525253     0.338624       1.0
# 269727  0.999993   0.983333  0.195402     0.494949     0.179894       1.0
# 269728  0.999993   0.983333  0.195402     0.494949     0.179894       1.0
# 269729  1.000000   0.850000  0.229885     0.585859     0.375661       1.0
# 269730  1.000000   0.883333  0.275862     0.585859     0.375661       1.0
#
#         cat__NOC  cat__Games  cat__Season  cat__City  cat__Sport  cat__Event  \
# ...

# %%
clustered_df.sample(30, random_state=42)
# Out:
#          num__ID  num__Year  num__age  num__height  num__weight  cat__Sex  \
# 81100   0.305444   0.533333  0.177641     0.488272     0.241808       1.0
# 123998  0.464299   0.766667  0.206897     0.525253     0.211640       1.0
# 31114   0.118566   0.666667  0.264368     0.414141     0.248677       1.0
# 248008  0.920521   0.333333  0.206897     0.488272     0.241808       1.0
# 1541    0.006307   0.533333  0.172414     0.444444     0.211640       1.0
# 69862   0.263797   0.966667  0.091954     0.525253     0.259259       1.0
# 51379   0.195759   0.566667  0.149425     0.575758     0.306878       1.0
# 19025   0.074500   0.983333  0.137931     0.575758     0.291005       1.0
# 135473  0.505370   0.466667  0.252874     0.484848     0.238095       1.0
# 35056   0.133783   0.766667  0.126437     0.515152     0.227513       1.0
# 221262  0.824194   0.300000  0.494253     0.488272     0.241808       1.0
# 58885   0.223678   0.200000  0.177641     0.488272     0.241808       1.0
# ...

# %% [markdown]
# ### Probar Detect_anomalies

# %%
# Probamos método detect_anomalies
from sklearn.ensemble import IsolationForest
pro.detect_anomalies(IsolationForest())

# %%
anomalies_df = pd.read_csv('EDA_10-11-2023/anomalies/data_anomalies 3.csv')
anomalies_df
# Out:
#          num__ID  num__Year  num__age  num__height  num__weight  cat__Sex  \
# 0       0.000000   0.800000  0.160920     0.535354     0.291005       1.0
# 1       0.000007   0.966667  0.149425     0.434343     0.185185       1.0
# 2       0.000015   0.200000  0.160920     0.488272     0.241808       1.0
# 3       0.000022   0.033333  0.275862     0.488272     0.241808       1.0
# 4       0.000030   0.766667  0.126437     0.585859     0.301587       0.0
# ...          ...        ...       ...          ...          ...       ...
# 269726  0.999985   0.666667  0.218391     0.525253     0.338624       1.0
# 269727  0.999993   0.983333  0.195402     0.494949     0.179894       1.0
# 269728  0.999993   0.983333  0.195402     0.494949     0.179894       1.0
# 269729  1.000000   0.850000  0.229885     0.585859     0.375661       1.0
# 269730  1.000000   0.883333  0.275862     0.585859     0.375661       1.0
#
#         cat__NOC  cat__Games  cat__Season  cat__City  cat__Sport  cat__Event  \
# ...

# %%
anomalies_df.sample(30, random_state=42)
# Out:
#          num__ID  num__Year  num__age  num__height  num__weight  cat__Sex  \
# 81100   0.305444   0.533333  0.177641     0.488272     0.241808       1.0
# 123998  0.464299   0.766667  0.206897     0.525253     0.211640       1.0
# 31114   0.118566   0.666667  0.264368     0.414141     0.248677       1.0
# 248008  0.920521   0.333333  0.206897     0.488272     0.241808       1.0
# 1541    0.006307   0.533333  0.172414     0.444444     0.211640       1.0
# 69862   0.263797   0.966667  0.091954     0.525253     0.259259       1.0
# 51379   0.195759   0.566667  0.149425     0.575758     0.306878       1.0
# 19025   0.074500   0.983333  0.137931     0.575758     0.291005       1.0
# 135473  0.505370   0.466667  0.252874     0.484848     0.238095       1.0
# 35056   0.133783   0.766667  0.126437     0.515152     0.227513       1.0
# 221262  0.824194   0.300000  0.494253     0.488272     0.241808       1.0
# 58885   0.223678   0.200000  0.177641     0.488272     0.241808       1.0
# ...

# %% [markdown]
# ### Probar profile

# %%
pro.profile()
# Out:
# /var/folders/99/5tksxy_97r1gt6jg9yrqqmy40000gn/T/ipykernel_18642/1296162028.py:173: PerformanceWarning:
#
# The following operation may generate 11178848772 cells in the resulting pandas object.
# El Kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior. Revise el código de las celdas para identificar una posible causa del error. Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información. Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %% [markdown]
# ### Probar clearGarbage

# %%
pro.clearGarbage()
# Out:
# Se ha eliminado el contenido de EDA_09-11-2023

# %% [markdown]
# ## 1.2 Caracterizar datos de Olimpiadas (2.0 puntos)
#
# A partir de la clase que hemos desarrollado previamente, procederemos a realizar un análisis exhaustivo de los datos proporcionados en el enunciado. Este análisis se presentará en forma de un informe contenido en el mismo Jupyter Notebook y abordará los siguientes puntos:
#
# 1. Introducción
#     - Se proporcionará una breve descripción del problema que estamos abordando y se explicará la metodología que se seguirá.
#
# Elaborar una breve introducción con todo lo necesario para entender qué realizarán durante su proyecto. La idea es que describan de manera formal el proyecto con sus propias palabras y logren describir algunos aspectos básicos tanto del dataset como del análisis a realizar sobre los datos.
#
# Por lo anterior, en esta sección ustedes deberán ser capaces de:
#
# - Describir la tarea asociada al dataset.
# - Describir brevemente los datos de entrada que les provee el problema.
# - Plantear hipótesis de cómo podrían abordar el problema.
#
# 2. Análisis del EDA (Análisis Exploratorio de Datos)
#     - Se discutirán las observaciones y conclusiones obtenidas acerca de los datos proporcionados. A lo largo de su respuesta, debe responder preguntas como:
#         - ¿Como se comportan las variables numéricas? ¿y las categóricas?
#         - ¿Existen valores nulos en el dataset? ¿En qué columnas? ¿Cuantos?
#         - ¿Cuáles son las categorías y frecuencias de las variables categóricas?
#         - ¿Existen datos duplicados en el conjunto?
#         - ¿Existen relaciones o patrones visuales entre las variables?
#         - ¿Existen anomalías notables o preocupantes en los datos?
# 3. Creación de Clusters y Anomalías
#     - Se justificará la elección del número de clusters y se aplicarán técnicas de clusterización para segmentar los datos.
# 4. Análisis de Resultados
#     - Se examinarán los resultados obtenidos a partir de los clústers y anomalías generadas. ¿Se logra una separación efectiva de los datos? Entregue una interpretación de lo que representa cada clúster y anomalía.
# 5. Conclusión
#     - Se resumirán las principales conclusiones del análisis y se destacarán las implicaciones prácticas de los resultados obtenidos.

# %% [markdown]
# # Introducción
#
#
# El proyecto a realizar consiste en abordar el análisis y caracterización de un conjunto de datos de los Juegos Olímpicos, con el objetivo de obtener información relevante y valiosa que permita comprender mejor el desarrollo y los patrones asociados a estos eventos deportivos a lo largo de los años.
#
# El dataset proporcionado contiene información sobre diversas ediciones de los Juegos Olímpicos con 271.116 observaciones correspondientes a cada atleta  y cuenta con las siguientes 13 variables:
# ```
# 'ID', 'Name', 'Sex', 'Team', 'NOC', 'Games', 'Year', 'Season', 'City', 'Sport', 'Event', 'Medal', 'age-height-weight'
# ```
#
# De lo anterior se puede apreciar que es una de las variables, 'age-height-weight', presenta datos no atómicos, lo que dificulta su uso para el análisis debido a la falta de claridad, la imposibilidad de realizar un análisis detallado, la incompatibilidad con visualizaciones y la necesidad de preprocesamiento. Para abordar esta limitación y aprovechar al máximo esta información, es esencial llevar a cabo una transformación de datos que permita la separación de estos atributos en columnas individuales. Esto facilitará el análisis de cada atributo por separado y permitirá la identificación de patrones y relaciones relevantes.
#
# El enfoque principal de este proyecto es la creación de una clase llamada Profiler, la cual,  permitirá caracterizar de manera automática y eficiente los datos recopilados de los Juegos Olímpicos. Para ello, desarrollaremos funcionalidades clave como la generación de resúmenes de variables, visualización de distribuciones, limpieza de datos y escalado. Además, propondremos un estudio de clusterización y detección de anomalías para comprender mejor los patrones y excepciones presentes en los datos.
#
# En síntesis, el proyecto se propone como un esfuerzo para proporcionar una comprensión profunda y significativa de los datos de los Juegos Olímpicos, contribuyendo así al éxito de los Juegos de Santiago 2023 y brindando una base sólida para futuras decisiones y análisis en el ámbito deportivo.

# %% [markdown]
# # Análisis exploratorio de datos
#
# En esta sección , se explorarán  en detalle los datos proporcionados para obtener una comprensión más profunda de su contenido y estructura gracias al método **summarize** de la clase **Profiler**, el cual caracteriza las variables, como también visualizar patrones y relaciones entre las variables a través del método **plot_vars** de la misma clase.
#
# En esta sección, se realiza una exploración detallada de los datos proporcionados para obtener una comprensión más profunda de su contenido y estructura. Se utilizan los métodos summarize y plot_vars de la clase Profiler para caracterizar y visualizar patrones y relaciones entre las variables.
#
# En primer lugar, se analizan las variables numéricas, como "ID" y "age-height-weight". La columna "ID" se presenta como una identificación única para cada participante, con 135,571 valores únicos, sin valores nulos ni extremos significativos, indicando una distribución equitativa. La variable compuesta "age-height-weight" se trata inicialmente como categórica y requiere un tratamiento adicional debido a sus 82,971 valores únicos.
#
# Por otro lado, se exploran las variables categóricas restantes. "Name", "Sex", "Team", "NOC", "Games", "Season", "City", "Sport", "Event", y "Medal". Estas muestran diversas características, desde la diversidad de nombres hasta la representación de equipos, comités olímpicos nacionales, y detalles de eventos. En todas estas variables se puede observar una gran cantidad de valores duplicados, lo que tiene sentido debido aa su característica categórica, más no se encontraron filas duplicadas en el set de datos. Se destaca la necesidad de abordar valores nulos y ausencia significativa de medallas en la variable "Medal" para un análisis más completo, debido a que el 85,33% de sus datos son nulos.
#
# Este análisis revela la riqueza de información contenida en las variables numéricas y categóricas, destacando áreas específicas que requieren atención y tratamiento adicional para un análisis de datos completo y preciso.
#
# Como la gran mayoría de las variables son tipo object, es complejo hacer un análisis de correlación entre variables basado en una matroz de correlación, como se haría comúnmente, en este caso, se utilizará el Coeficiente V de Cramer para llevar a cabo este análisis. Algunas relaciones que no llaman de gran manera la atención, es el alto valor del Coeficiente V de Cramer entre las variables "City", "Games" y "Season", teniendo en cuenta que la elección de la ciudad para los juegos comúnmente tendra que ver con si los juegos son de verano o invierno, siguiendo el mismo razonamiento para la temporada del año. Algo similar ocurre con la variables "Games", cuyo coeficiente llega a 1 con las variables "Season" y "City". Tampoco sorpende el alto coeficiente entre las variables "Sex" y "Event", dado que las competencias están divididas entre hombres y mujeres. Si es destacable la alta relación entre las variables Medal con Teams y Names, lo que hace alusión que calramente hay equipos que obtienen mayor cantidad de medallas, al igual que personas que haan sido más galardonadas a lo lartgo de la historia.
#
# La única anomalía destacable y relevante para el desarrollo del trabajo es la existencia de la columna "age-height-weight", la que incluye los valores de edad, altura y peso de las y los competidores. Aquí se puede ver la existencia de hartos datos nulos, que no pueden ser contabilizados por el método summerize sin esta ser antes dividida y que debe ser solucionado antes de llevar a cabo cualquier clusterización y proceso de detección de anomalías.
#
# Al revisar la distribución de los datos, se puede ver en que general existe un gran desequilibrio, sobretodo en variables como "Event", "NOC", "Season", "Sex", "Sport", "Team" e, incluso, "Year". Esto puede tener que ver con razones históricas, por ejemplo: sexismo en el ámbito deportivo, lo que ha significado una mayor participación de hombres en los juegos olímpicos a lo largo de la historia; los países con mayor población presentan mayor cantidad de competidores y generan mejores resultados que países con menor población y desarrollo del deporte; los eventos deportivos van cambiando año a año, algunos desapareciendo y otros siendo incluidos con el pasar del tiempo; algunos eventos históricos pueden haber significado la participación de un mayor o menor número de participantes de ciertos países, además de la participación de los comités olímpicos de algunos paísea bajo un nombre distinto debido a sanciones internacionales.
#
# Para la limpieza de los datos, se decidió usar criterios distintos para los datos numéricos y categóricos. En particular, los datos numéricos faltantes fueron rellenados con la media de los datos de cada columna, y los datos categóricos fueron rellenados con el valor "No Value". Esto último debido a que la única columna categórica con valores nulos era la variable "Medal", por lo que si, por ejemplo, se rellenaban los valores faltantes con la moda de los datos, esto podría ensuciar los resultados. A su vez, se decidió no eliminar las filas con datos nulos debido a que se perderían alrededor de un 90% del total de los datos.
#
# Para realizar el escalamiento, se utilizó un escalador logarítmico y un escalador de mínimos y máximos para los valores numéricos como se indicó en el enunciado del proyecto, y se decidió agregar más escaladores. Esto debido a que los datos numéricos estudiados no presentan mayores outliers, por lo que la necesidad de escalamiento no es mayor. En cuanto a los datos categóricos, se probó utilizando un OneHotEncoder y un OrdinalEncoder. El primero no permitió codificar las columnas con un gran número de categorías, como lo son "NOC", "Team", "Event", entre otros. Solo permitió clasificar variables con pocas categorías como "Sex", "Medals" y "Season", lo que dejaba alrededor de 5 categorías fuera del análisis. Luego se intentó utilizando el OrdinalEncoder, el cual permitió asignar un valor numérico a cada una de a las categorías de las variables a codificar, dejando solamente fuera la variable "Name", que se quitó debido a que no entragaba mayor información.

# %% [markdown]
# # Creación de clusters y anomalías

# %% [markdown]
# Al pasar a la clusterización de los datos, se decidió utilizar el método del codo para definir la cantidad de segmentos en los cuales se agruparía la data (clusters). Del gráfico que pudo notar que la diferencia cuadrática entre la varianza de los datos disminuye de forma relevante hasta que se llega a los 3 clusters, por lo que se decidió esta cantidad de segmentos.

# %% [markdown]
# ![Método del codo](EDA_10-11-2023/clusters/elbow_method.png)

# %% [markdown]
# El algoritmo elegido para realizar la clusterización fue MiniBatchKMeans. Este es una variación de KMeans que utiliza mini lotes (muestras aleatoria más pequeñas) en lugar de procesar todo el conjunto de datos de una sola vez, haciéndolo más eficiente computacionalmente que KMeans y otros algorítmos. En particular, se probó también con KMeans, SpectralClustering y AffinityPropagation. Todos ellos entregaron resultados cais idénticos al KMeans por lotes pequeños pero en un mayor tiempo de compilación, a excepeción de AffinityPropagation, el cual agotó la memoria del entorno y no logró entregar resultados.
#
# Para realizar la detección de anomalías se utilizó el algoritmo IsolationForest. Se decidió usar este algoritmo ya que utiliza árboles de decisión para dividir el espacio de características y aislar las observaciones anómalas, lo que permite realizar particiones rápidas y eficientes. Además, es un algortitmo poco sensible a la escalabilidad de los datos que tampoco se ve afectado por la presencia de características irrelevantes. En el caso de nuestro dataset, no se tiene muy clara de antemano la relevancia de cada variable, por lo que esta última es una característica conveniente. Finalmente, IsolationForest maneja de buena manera conjuntos de datos desequilibrados. Si se vuelve a revisar la distribución de datos de variables como NOC, Season, Sex, Team, Sport e incluso Year, se puede ver el gran desbalance existente dentro de algunas columnas del set de datos.

# %% [markdown]
# # Análisis de resultados

# %% [markdown]
# El resultado gráfico de los clusters se puede ver a continuación:

# %% [markdown]
# ![Clusters 2D](EDA_10-11-2023/clusters/data_projection.png)

# %% [markdown]
# De aquí se puede observar que hay una clara división de los clusters respecto del eje x del espacio de datos proyectado a dos dimensiones. Y analizando la columna "clusters" que se incorporó al Dataframe original. En primera instancia, se pensó que la variable con mayor relevancia a la hora de definir los cluster fue "Medal", es decir, que la segmentación se había sido definida por el tipo de medalla (oro, plata y bronce) que habían ganado los participantes de los juegos olímpicos. En línea con lo anterior, era posible argumentar que las anomalías que pueden verse en el siguiente gráfico (representadas en color morado y con un valor -1), representaban en su gran mayoría a personas que no obtuvieron medallas en los juegos y que fueron clasificadas de igual manera en uno de los clusters.

# %% [markdown]
# ![Anomalies 2D](EDA_10-11-2023/anomalies/anomalies_plot.png)

# %% [markdown]
# Luego de analizar las columnas de clusters y anomalías entregadas por ambos métodos, se pudo observar que la hipótesis era incorrecta y que la clusterización no tiene a la columna "Medal" como variable principal. Además, observando el gráfico de anomalías, es posible ver una menor concentración de anomalías en el segundo cluster, es decir, que le segundo cluster fue el mejor clasificado con respecto de los otros dos. Lo anterior puede deberse al desbalance de los datos y a la imputación que se hizo a los datos para hacerse cargo de la cantidad de valores nulos.

# %% [markdown]
# # Conclusión

# %% [markdown]
# En este proyecto de análisis y caracterización de datos de los Juegos Olímpicos, se han obtenido varias conclusiones clave que arrojan luz sobre diferentes aspectos de la información proporcionada. A continuación, se resumen las principales conclusiones y se destacan las implicaciones prácticas de los resultados obtenidos.
#
# Al realizar la transformación de los datos, la presencia de la variable compuesta 'age-height-weight' presentó un desafío inicial debido a su naturaleza no atómica. La decisión de llevar a cabo una transformación de datos, separando estos atributos en columnas individuales, demostró ser esencial para facilitar un análisis más detallado y la identificación de patrones y relaciones relevantes. Esta transformación permitió aprovechar al máximo la información contenida en estos atributos. A pesar de que no se logró crear un cósigo que identificara automáticamente este tipo de columnas, se puede decir que el método creado para la limpieza y transformación de los datos es exitoso.
#
# El análisis exploratorio reveló la diversidad y complejidad de los datos de los Juegos Olímpicos. Se identificaron áreas que requieren atención, como la presencia de valores nulos en la variable 'Medal', la cual es crucial para un análisis más completo. Además, se destacó el desequilibrio en la distribución de varias variables categóricas, lo que puede deberse a razones históricas y eventos específicos en la historia de los Juegos Olímpicos.
#
# La estrategia de limpieza y escalamiento de datos abordó eficazmente la gestión de valores nulos y la preparación de datos para análisis posterior. La elección de llenar los valores faltantes de datos numéricos con la media de cada columna y los datos categóricos con "No Value" se basó en la naturaleza de cada tipo de variable y la necesidad de mantener la integridad de los datos.
#
# La aplicación del método del codo para determinar el número óptimo de clusters resultó en la elección de tres clusters. La utilización del algoritmo MiniBatchKMeans para la clusterización demostró ser eficiente computacionalmente, ofreciendo resultados similares a otros algoritmos probados. La detección de anomalías mediante IsolationForest permitió identificar observaciones atípicas de manera eficaz, especialmente en un conjunto de datos desequilibrado.
#
# La identificación de una clara división de los clusters en el espacio de datos proyectado a dos dimensiones tiene importantes implicaciones prácticas que pueden guiar futuras decisiones y análisis en el contexto de los Juegos Olímpicos. Aunque inicialmente se pensó que la variable "Medal" sería determinante en la segmentación de los clusters, los resultados revelaron un patrón más complejo. Será importante tener en cuenta para futuros análisis que la falta de dominio sobre las variables clave para la segmentación destaca la importancia de un enfoque exploratorio y sin prejuicios en el análisis de datos. En futuras investigaciones, se debería realizar una reevaluación de las variables consideradas relevantes, priorizando aquellas que realmente influyen en la agrupación de los atletas.
#
# Se pudo observar una menor concentración de anomalías en el segundo cluster, lo que sugiere que este fue mejor clasificado en comparación con los otros dos. Este hallazgo resalta la importancia de abordar el desbalance de datos de manera más efectiva, ya que puede afectar la calidad de la clusterización y la detección de anomalías. Además, esta presencia de anomalías en los clusters podría estar influenciada por la imputación de valores nulos. Sería esencial revisar y perfeccionar las técnicas de imputación utilizadas, considerando en mayor medida el impacto que estas pueden tener en la formación de clusters y en la identificación de anomalías.
